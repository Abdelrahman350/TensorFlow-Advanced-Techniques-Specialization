# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Get the data from UCI dataset
URL = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00242/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URL)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 222.5163 - y1_output_loss: 105.8822 - y2_output_loss: 114.5223 - y1_output_root_mean_squared_error: 10.3391 - y2_output_root_mean_squared_error: 10.7526 - val_loss: 38.7961 - val_y1_output_loss: 16.4426 - val_y2_output_loss: 21.3599 - val_y1_output_root_mean_squared_error: 4.1109 - val_y2_output_root_mean_squared_error: 4.6794
# Epoch 2/500
# 614/614 [==============================] - 0s 131us/sample - loss: 33.6144 - y1_output_loss: 13.2031 - y2_output_loss: 20.7971 - y1_output_root_mean_squared_error: 3.6199 - y2_output_root_mean_squared_error: 4.5288 - val_loss: 42.4692 - val_y1_output_loss: 13.4032 - val_y2_output_loss: 30.7154 - val_y1_output_root_mean_squared_error: 3.6474 - val_y2_output_root_mean_squared_error: 5.4005
# Epoch 3/500
# 614/614 [==============================] - 0s 128us/sample - loss: 23.7339 - y1_output_loss: 9.4236 - y2_output_loss: 14.2279 - y1_output_root_mean_squared_error: 3.0820 - y2_output_root_mean_squared_error: 3.7730 - val_loss: 47.0216 - val_y1_output_loss: 11.8342 - val_y2_output_loss: 33.6738 - val_y1_output_root_mean_squared_error: 3.5016 - val_y2_output_root_mean_squared_error: 5.8958
# Epoch 4/500
# 614/614 [==============================] - 0s 129us/sample - loss: 23.9435 - y1_output_loss: 9.3103 - y2_output_loss: 14.8476 - y1_output_root_mean_squared_error: 3.0583 - y2_output_root_mean_squared_error: 3.8197 - val_loss: 42.9004 - val_y1_output_loss: 10.8167 - val_y2_output_loss: 34.0395 - val_y1_output_root_mean_squared_error: 3.2816 - val_y2_output_root_mean_squared_error: 5.6685
# Epoch 5/500
# 614/614 [==============================] - 0s 128us/sample - loss: 23.1345 - y1_output_loss: 8.7448 - y2_output_loss: 14.3448 - y1_output_root_mean_squared_error: 2.9578 - y2_output_root_mean_squared_error: 3.7929 - val_loss: 26.1846 - val_y1_output_loss: 10.9097 - val_y2_output_loss: 14.3311 - val_y1_output_root_mean_squared_error: 3.3657 - val_y2_output_root_mean_squared_error: 3.8544
# Epoch 6/500
# 614/614 [==============================] - 0s 125us/sample - loss: 21.8758 - y1_output_loss: 8.9059 - y2_output_loss: 12.8524 - y1_output_root_mean_squared_error: 2.9964 - y2_output_root_mean_squared_error: 3.5913 - val_loss: 43.2100 - val_y1_output_loss: 13.9366 - val_y2_output_loss: 27.8615 - val_y1_output_root_mean_squared_error: 3.7983 - val_y2_output_root_mean_squared_error: 5.3650
# Epoch 7/500
# 614/614 [==============================] - 0s 127us/sample - loss: 21.9951 - y1_output_loss: 8.5587 - y2_output_loss: 13.3871 - y1_output_root_mean_squared_error: 2.9258 - y2_output_root_mean_squared_error: 3.6653 - val_loss: 49.0040 - val_y1_output_loss: 11.7787 - val_y2_output_loss: 36.0882 - val_y1_output_root_mean_squared_error: 3.4760 - val_y2_output_root_mean_squared_error: 6.0763
# Epoch 8/500
# 614/614 [==============================] - 0s 123us/sample - loss: 20.9030 - y1_output_loss: 8.2321 - y2_output_loss: 12.6139 - y1_output_root_mean_squared_error: 2.8747 - y2_output_root_mean_squared_error: 3.5552 - val_loss: 40.0872 - val_y1_output_loss: 11.9823 - val_y2_output_loss: 26.9068 - val_y1_output_root_mean_squared_error: 3.5176 - val_y2_output_root_mean_squared_error: 5.2644
# Epoch 9/500
# 614/614 [==============================] - 0s 119us/sample - loss: 19.0747 - y1_output_loss: 7.7533 - y2_output_loss: 11.2618 - y1_output_root_mean_squared_error: 2.7816 - y2_output_root_mean_squared_error: 3.3672 - val_loss: 26.0937 - val_y1_output_loss: 12.1029 - val_y2_output_loss: 13.9854 - val_y1_output_root_mean_squared_error: 3.4898 - val_y2_output_root_mean_squared_error: 3.7303
# Epoch 10/500
# 614/614 [==============================] - 0s 120us/sample - loss: 24.1993 - y1_output_loss: 8.8771 - y2_output_loss: 15.4377 - y1_output_root_mean_squared_error: 2.9662 - y2_output_root_mean_squared_error: 3.9244 - val_loss: 23.8413 - val_y1_output_loss: 9.3524 - val_y2_output_loss: 13.9557 - val_y1_output_root_mean_squared_error: 3.0843 - val_y2_output_root_mean_squared_error: 3.7853
# Epoch 11/500
# 614/614 [==============================] - 0s 123us/sample - loss: 17.1870 - y1_output_loss: 7.1879 - y2_output_loss: 9.9402 - y1_output_root_mean_squared_error: 2.6801 - y2_output_root_mean_squared_error: 3.1630 - val_loss: 19.5235 - val_y1_output_loss: 8.7901 - val_y2_output_loss: 10.4227 - val_y1_output_root_mean_squared_error: 2.9822 - val_y2_output_root_mean_squared_error: 3.2604
# Epoch 12/500
# 614/614 [==============================] - 0s 124us/sample - loss: 18.9577 - y1_output_loss: 7.4668 - y2_output_loss: 11.3919 - y1_output_root_mean_squared_error: 2.7430 - y2_output_root_mean_squared_error: 3.3814 - val_loss: 24.2127 - val_y1_output_loss: 8.1435 - val_y2_output_loss: 15.2879 - val_y1_output_root_mean_squared_error: 2.9013 - val_y2_output_root_mean_squared_error: 3.9743
# Epoch 13/500
# 614/614 [==============================] - 0s 124us/sample - loss: 17.2885 - y1_output_loss: 6.9271 - y2_output_loss: 10.2785 - y1_output_root_mean_squared_error: 2.6340 - y2_output_root_mean_squared_error: 3.2173 - val_loss: 34.0727 - val_y1_output_loss: 11.2850 - val_y2_output_loss: 22.2286 - val_y1_output_root_mean_squared_error: 3.3812 - val_y2_output_root_mean_squared_error: 4.7582
# Epoch 14/500
# 614/614 [==============================] - 0s 121us/sample - loss: 18.1062 - y1_output_loss: 6.6892 - y2_output_loss: 11.4438 - y1_output_root_mean_squared_error: 2.5894 - y2_output_root_mean_squared_error: 3.3766 - val_loss: 18.4424 - val_y1_output_loss: 7.3341 - val_y2_output_loss: 10.8268 - val_y1_output_root_mean_squared_error: 2.7241 - val_y2_output_root_mean_squared_error: 3.3199
# Epoch 15/500
# 614/614 [==============================] - 0s 120us/sample - loss: 16.6723 - y1_output_loss: 6.6351 - y2_output_loss: 10.1908 - y1_output_root_mean_squared_error: 2.5574 - y2_output_root_mean_squared_error: 3.1831 - val_loss: 16.1770 - val_y1_output_loss: 6.5815 - val_y2_output_loss: 9.1903 - val_y1_output_root_mean_squared_error: 2.6033 - val_y2_output_root_mean_squared_error: 3.0659
# Epoch 16/500
# 614/614 [==============================] - 0s 123us/sample - loss: 14.7081 - y1_output_loss: 6.0661 - y2_output_loss: 8.5285 - y1_output_root_mean_squared_error: 2.4728 - y2_output_root_mean_squared_error: 2.9315 - val_loss: 17.9267 - val_y1_output_loss: 7.1817 - val_y2_output_loss: 10.2232 - val_y1_output_root_mean_squared_error: 2.7148 - val_y2_output_root_mean_squared_error: 3.2491
# Epoch 17/500
# 614/614 [==============================] - 0s 120us/sample - loss: 16.1897 - y1_output_loss: 6.0184 - y2_output_loss: 10.0483 - y1_output_root_mean_squared_error: 2.4615 - y2_output_root_mean_squared_error: 3.1829 - val_loss: 16.1810 - val_y1_output_loss: 6.3436 - val_y2_output_loss: 9.5550 - val_y1_output_root_mean_squared_error: 2.5471 - val_y2_output_root_mean_squared_error: 3.1134
# Epoch 18/500
# 614/614 [==============================] - 0s 120us/sample - loss: 14.8954 - y1_output_loss: 5.9844 - y2_output_loss: 9.0860 - y1_output_root_mean_squared_error: 2.4340 - y2_output_root_mean_squared_error: 2.9952 - val_loss: 17.7393 - val_y1_output_loss: 6.4832 - val_y2_output_loss: 10.7249 - val_y1_output_root_mean_squared_error: 2.5788 - val_y2_output_root_mean_squared_error: 3.3301
# Epoch 19/500
# 614/614 [==============================] - 0s 123us/sample - loss: 14.3043 - y1_output_loss: 5.6852 - y2_output_loss: 8.6174 - y1_output_root_mean_squared_error: 2.3724 - y2_output_root_mean_squared_error: 2.9455 - val_loss: 16.2145 - val_y1_output_loss: 5.9805 - val_y2_output_loss: 9.7385 - val_y1_output_root_mean_squared_error: 2.4802 - val_y2_output_root_mean_squared_error: 3.1723
# Epoch 20/500
# 614/614 [==============================] - 0s 123us/sample - loss: 13.6190 - y1_output_loss: 5.4465 - y2_output_loss: 8.1979 - y1_output_root_mean_squared_error: 2.3219 - y2_output_root_mean_squared_error: 2.8684 - val_loss: 21.9091 - val_y1_output_loss: 7.9297 - val_y2_output_loss: 13.4130 - val_y1_output_root_mean_squared_error: 2.8425 - val_y2_output_root_mean_squared_error: 3.7188
# Epoch 21/500
# 614/614 [==============================] - 0s 122us/sample - loss: 12.9552 - y1_output_loss: 5.2415 - y2_output_loss: 7.7813 - y1_output_root_mean_squared_error: 2.2924 - y2_output_root_mean_squared_error: 2.7749 - val_loss: 15.3511 - val_y1_output_loss: 5.8289 - val_y2_output_loss: 9.1686 - val_y1_output_root_mean_squared_error: 2.4542 - val_y2_output_root_mean_squared_error: 3.0542
# Epoch 22/500
# 614/614 [==============================] - 0s 122us/sample - loss: 12.4821 - y1_output_loss: 4.8809 - y2_output_loss: 7.7763 - y1_output_root_mean_squared_error: 2.2102 - y2_output_root_mean_squared_error: 2.7563 - val_loss: 27.3785 - val_y1_output_loss: 7.1002 - val_y2_output_loss: 20.9163 - val_y1_output_root_mean_squared_error: 2.6623 - val_y2_output_root_mean_squared_error: 4.5045
# Epoch 23/500
# 614/614 [==============================] - 0s 122us/sample - loss: 12.4353 - y1_output_loss: 4.8499 - y2_output_loss: 7.5077 - y1_output_root_mean_squared_error: 2.2052 - y2_output_root_mean_squared_error: 2.7518 - val_loss: 14.8675 - val_y1_output_loss: 5.3185 - val_y2_output_loss: 9.1561 - val_y1_output_root_mean_squared_error: 2.3283 - val_y2_output_root_mean_squared_error: 3.0735
# Epoch 24/500
# 614/614 [==============================] - 0s 124us/sample - loss: 12.3571 - y1_output_loss: 4.8550 - y2_output_loss: 7.4342 - y1_output_root_mean_squared_error: 2.2087 - y2_output_root_mean_squared_error: 2.7348 - val_loss: 14.1987 - val_y1_output_loss: 5.1228 - val_y2_output_loss: 8.8226 - val_y1_output_root_mean_squared_error: 2.2981 - val_y2_output_root_mean_squared_error: 2.9862
# Epoch 25/500
# 614/614 [==============================] - 0s 124us/sample - loss: 13.3845 - y1_output_loss: 4.9278 - y2_output_loss: 8.3527 - y1_output_root_mean_squared_error: 2.2292 - y2_output_root_mean_squared_error: 2.9009 - val_loss: 15.2306 - val_y1_output_loss: 5.1073 - val_y2_output_loss: 9.7497 - val_y1_output_root_mean_squared_error: 2.3016 - val_y2_output_root_mean_squared_error: 3.1517
# Epoch 26/500
# 614/614 [==============================] - 0s 124us/sample - loss: 12.6925 - y1_output_loss: 4.7538 - y2_output_loss: 7.9318 - y1_output_root_mean_squared_error: 2.1887 - y2_output_root_mean_squared_error: 2.8111 - val_loss: 15.7796 - val_y1_output_loss: 5.3453 - val_y2_output_loss: 10.1300 - val_y1_output_root_mean_squared_error: 2.3492 - val_y2_output_root_mean_squared_error: 3.2032
# Epoch 27/500
# 614/614 [==============================] - 0s 121us/sample - loss: 11.9528 - y1_output_loss: 4.7664 - y2_output_loss: 7.2247 - y1_output_root_mean_squared_error: 2.1769 - y2_output_root_mean_squared_error: 2.6859 - val_loss: 23.1625 - val_y1_output_loss: 5.6248 - val_y2_output_loss: 17.1186 - val_y1_output_root_mean_squared_error: 2.3907 - val_y2_output_root_mean_squared_error: 4.1770
# Epoch 28/500
# 614/614 [==============================] - 0s 124us/sample - loss: 12.9786 - y1_output_loss: 4.4891 - y2_output_loss: 8.4095 - y1_output_root_mean_squared_error: 2.1207 - y2_output_root_mean_squared_error: 2.9123 - val_loss: 25.0438 - val_y1_output_loss: 6.5859 - val_y2_output_loss: 18.1072 - val_y1_output_root_mean_squared_error: 2.5773 - val_y2_output_root_mean_squared_error: 4.2897
# Epoch 29/500
# 614/614 [==============================] - 0s 118us/sample - loss: 10.4067 - y1_output_loss: 4.1697 - y2_output_loss: 6.3439 - y1_output_root_mean_squared_error: 2.0299 - y2_output_root_mean_squared_error: 2.5072 - val_loss: 26.5472 - val_y1_output_loss: 7.1630 - val_y2_output_loss: 19.3544 - val_y1_output_root_mean_squared_error: 2.6614 - val_y2_output_root_mean_squared_error: 4.4118
# Epoch 30/500
# 614/614 [==============================] - 0s 119us/sample - loss: 11.4384 - y1_output_loss: 4.5499 - y2_output_loss: 7.3031 - y1_output_root_mean_squared_error: 2.1110 - y2_output_root_mean_squared_error: 2.6424 - val_loss: 68.1697 - val_y1_output_loss: 12.1925 - val_y2_output_loss: 57.2815 - val_y1_output_root_mean_squared_error: 3.4867 - val_y2_output_root_mean_squared_error: 7.4842
# Epoch 31/500
# 614/614 [==============================] - 0s 119us/sample - loss: 12.0880 - y1_output_loss: 4.5376 - y2_output_loss: 8.1367 - y1_output_root_mean_squared_error: 2.0796 - y2_output_root_mean_squared_error: 2.7863 - val_loss: 58.1538 - val_y1_output_loss: 25.3235 - val_y2_output_loss: 36.1070 - val_y1_output_root_mean_squared_error: 4.9153 - val_y2_output_root_mean_squared_error: 5.8304
# Epoch 32/500
# 614/614 [==============================] - 0s 118us/sample - loss: 15.7752 - y1_output_loss: 6.0124 - y2_output_loss: 9.7969 - y1_output_root_mean_squared_error: 2.4364 - y2_output_root_mean_squared_error: 3.1367 - val_loss: 12.8934 - val_y1_output_loss: 3.5783 - val_y2_output_loss: 8.8377 - val_y1_output_root_mean_squared_error: 1.9274 - val_y2_output_root_mean_squared_error: 3.0296
# Epoch 33/500
# 614/614 [==============================] - 0s 119us/sample - loss: 9.4907 - y1_output_loss: 3.5242 - y2_output_loss: 5.8949 - y1_output_root_mean_squared_error: 1.8857 - y2_output_root_mean_squared_error: 2.4362 - val_loss: 11.3457 - val_y1_output_loss: 3.7906 - val_y2_output_loss: 7.2762 - val_y1_output_root_mean_squared_error: 1.9780 - val_y2_output_root_mean_squared_error: 2.7264
# Epoch 34/500
# 614/614 [==============================] - 0s 123us/sample - loss: 10.1920 - y1_output_loss: 3.7591 - y2_output_loss: 6.4397 - y1_output_root_mean_squared_error: 1.9409 - y2_output_root_mean_squared_error: 2.5348 - val_loss: 15.4655 - val_y1_output_loss: 4.2477 - val_y2_output_loss: 10.9588 - val_y1_output_root_mean_squared_error: 2.0939 - val_y2_output_root_mean_squared_error: 3.3288
# Epoch 35/500
# 614/614 [==============================] - 0s 124us/sample - loss: 9.4589 - y1_output_loss: 3.4100 - y2_output_loss: 5.9678 - y1_output_root_mean_squared_error: 1.8548 - y2_output_root_mean_squared_error: 2.4533 - val_loss: 10.4294 - val_y1_output_loss: 2.9357 - val_y2_output_loss: 7.1336 - val_y1_output_root_mean_squared_error: 1.7420 - val_y2_output_root_mean_squared_error: 2.7194
# Epoch 36/500
# 614/614 [==============================] - 0s 120us/sample - loss: 9.6021 - y1_output_loss: 3.4786 - y2_output_loss: 6.4224 - y1_output_root_mean_squared_error: 1.8556 - y2_output_root_mean_squared_error: 2.4817 - val_loss: 34.4921 - val_y1_output_loss: 7.3339 - val_y2_output_loss: 28.3266 - val_y1_output_root_mean_squared_error: 2.6847 - val_y2_output_root_mean_squared_error: 5.2235
# Epoch 37/500
# 614/614 [==============================] - 0s 123us/sample - loss: 9.7807 - y1_output_loss: 3.3342 - y2_output_loss: 6.3575 - y1_output_root_mean_squared_error: 1.8339 - y2_output_root_mean_squared_error: 2.5333 - val_loss: 8.6720 - val_y1_output_loss: 2.5411 - val_y2_output_loss: 5.8598 - val_y1_output_root_mean_squared_error: 1.6239 - val_y2_output_root_mean_squared_error: 2.4566
# Epoch 38/500
# 614/614 [==============================] - 0s 131us/sample - loss: 9.2447 - y1_output_loss: 3.1958 - y2_output_loss: 5.9697 - y1_output_root_mean_squared_error: 1.7958 - y2_output_root_mean_squared_error: 2.4535 - val_loss: 12.0210 - val_y1_output_loss: 3.8810 - val_y2_output_loss: 8.0902 - val_y1_output_root_mean_squared_error: 1.9887 - val_y2_output_root_mean_squared_error: 2.8401
# Epoch 39/500
# 614/614 [==============================] - 0s 124us/sample - loss: 9.3185 - y1_output_loss: 3.0698 - y2_output_loss: 6.1695 - y1_output_root_mean_squared_error: 1.7595 - y2_output_root_mean_squared_error: 2.4945 - val_loss: 13.5640 - val_y1_output_loss: 4.0584 - val_y2_output_loss: 9.2531 - val_y1_output_root_mean_squared_error: 2.0220 - val_y2_output_root_mean_squared_error: 3.0783
# Epoch 40/500
# 614/614 [==============================] - 0s 127us/sample - loss: 8.4279 - y1_output_loss: 3.1035 - y2_output_loss: 5.2685 - y1_output_root_mean_squared_error: 1.7644 - y2_output_root_mean_squared_error: 2.3053 - val_loss: 14.5065 - val_y1_output_loss: 4.2105 - val_y2_output_loss: 10.2222 - val_y1_output_root_mean_squared_error: 2.0345 - val_y2_output_root_mean_squared_error: 3.2198
# Epoch 41/500
# 614/614 [==============================] - 0s 122us/sample - loss: 8.5337 - y1_output_loss: 2.7218 - y2_output_loss: 5.8335 - y1_output_root_mean_squared_error: 1.6563 - y2_output_root_mean_squared_error: 2.4063 - val_loss: 9.5704 - val_y1_output_loss: 3.1467 - val_y2_output_loss: 6.2513 - val_y1_output_root_mean_squared_error: 1.7948 - val_y2_output_root_mean_squared_error: 2.5197
# Epoch 42/500
# 614/614 [==============================] - 0s 122us/sample - loss: 8.7519 - y1_output_loss: 3.0678 - y2_output_loss: 5.8106 - y1_output_root_mean_squared_error: 1.7295 - y2_output_root_mean_squared_error: 2.4002 - val_loss: 11.2267 - val_y1_output_loss: 4.3809 - val_y2_output_loss: 6.9272 - val_y1_output_root_mean_squared_error: 2.0857 - val_y2_output_root_mean_squared_error: 2.6223
# Epoch 43/500
# 614/614 [==============================] - 0s 123us/sample - loss: 7.7848 - y1_output_loss: 2.7907 - y2_output_loss: 4.9276 - y1_output_root_mean_squared_error: 1.6777 - y2_output_root_mean_squared_error: 2.2294 - val_loss: 8.3861 - val_y1_output_loss: 2.2297 - val_y2_output_loss: 5.8743 - val_y1_output_root_mean_squared_error: 1.5218 - val_y2_output_root_mean_squared_error: 2.4638
# Epoch 44/500
# 614/614 [==============================] - 0s 123us/sample - loss: 7.9772 - y1_output_loss: 2.6068 - y2_output_loss: 5.3882 - y1_output_root_mean_squared_error: 1.6088 - y2_output_root_mean_squared_error: 2.3214 - val_loss: 13.7692 - val_y1_output_loss: 3.5720 - val_y2_output_loss: 9.8944 - val_y1_output_root_mean_squared_error: 1.9010 - val_y2_output_root_mean_squared_error: 3.1867
# Epoch 45/500
# 614/614 [==============================] - 0s 124us/sample - loss: 7.9696 - y1_output_loss: 2.7627 - y2_output_loss: 5.2639 - y1_output_root_mean_squared_error: 1.6613 - y2_output_root_mean_squared_error: 2.2824 - val_loss: 12.2556 - val_y1_output_loss: 4.1705 - val_y2_output_loss: 8.3648 - val_y1_output_root_mean_squared_error: 2.0238 - val_y2_output_root_mean_squared_error: 2.8566
# Epoch 46/500
# 614/614 [==============================] - 0s 123us/sample - loss: 7.1104 - y1_output_loss: 2.4917 - y2_output_loss: 4.6532 - y1_output_root_mean_squared_error: 1.5729 - y2_output_root_mean_squared_error: 2.1532 - val_loss: 12.2554 - val_y1_output_loss: 2.6740 - val_y2_output_loss: 9.1388 - val_y1_output_root_mean_squared_error: 1.6639 - val_y2_output_root_mean_squared_error: 3.0801
# Epoch 47/500
# 614/614 [==============================] - 0s 120us/sample - loss: 6.9089 - y1_output_loss: 2.3387 - y2_output_loss: 4.6000 - y1_output_root_mean_squared_error: 1.5279 - y2_output_root_mean_squared_error: 2.1387 - val_loss: 20.7632 - val_y1_output_loss: 5.8150 - val_y2_output_loss: 15.2959 - val_y1_output_root_mean_squared_error: 2.3545 - val_y2_output_root_mean_squared_error: 3.9012
# Epoch 48/500
# 614/614 [==============================] - 0s 121us/sample - loss: 9.2852 - y1_output_loss: 2.7920 - y2_output_loss: 6.4774 - y1_output_root_mean_squared_error: 1.6744 - y2_output_root_mean_squared_error: 2.5459 - val_loss: 10.8047 - val_y1_output_loss: 2.1534 - val_y2_output_loss: 8.6178 - val_y1_output_root_mean_squared_error: 1.4903 - val_y2_output_root_mean_squared_error: 2.9298
# Epoch 49/500
# 614/614 [==============================] - 0s 119us/sample - loss: 6.9650 - y1_output_loss: 2.2127 - y2_output_loss: 4.6935 - y1_output_root_mean_squared_error: 1.4944 - y2_output_root_mean_squared_error: 2.1752 - val_loss: 9.0457 - val_y1_output_loss: 2.4375 - val_y2_output_loss: 6.4029 - val_y1_output_root_mean_squared_error: 1.5620 - val_y2_output_root_mean_squared_error: 2.5702
# Epoch 50/500
# 614/614 [==============================] - 0s 119us/sample - loss: 7.1966 - y1_output_loss: 2.3456 - y2_output_loss: 4.8581 - y1_output_root_mean_squared_error: 1.5232 - y2_output_root_mean_squared_error: 2.2083 - val_loss: 10.6373 - val_y1_output_loss: 2.1082 - val_y2_output_loss: 8.1965 - val_y1_output_root_mean_squared_error: 1.4709 - val_y2_output_root_mean_squared_error: 2.9110
# Epoch 51/500
# 614/614 [==============================] - 0s 120us/sample - loss: 6.8877 - y1_output_loss: 2.1046 - y2_output_loss: 4.7397 - y1_output_root_mean_squared_error: 1.4562 - y2_output_root_mean_squared_error: 2.1834 - val_loss: 7.3608 - val_y1_output_loss: 1.7819 - val_y2_output_loss: 5.3521 - val_y1_output_root_mean_squared_error: 1.3595 - val_y2_output_root_mean_squared_error: 2.3479
# Epoch 52/500
# 614/614 [==============================] - 0s 120us/sample - loss: 6.6537 - y1_output_loss: 2.2481 - y2_output_loss: 4.3717 - y1_output_root_mean_squared_error: 1.5014 - y2_output_root_mean_squared_error: 2.0975 - val_loss: 11.8307 - val_y1_output_loss: 2.8095 - val_y2_output_loss: 8.9066 - val_y1_output_root_mean_squared_error: 1.6635 - val_y2_output_root_mean_squared_error: 3.0105
# Epoch 53/500
# 614/614 [==============================] - 0s 119us/sample - loss: 6.5799 - y1_output_loss: 2.0770 - y2_output_loss: 4.4953 - y1_output_root_mean_squared_error: 1.4395 - y2_output_root_mean_squared_error: 2.1232 - val_loss: 12.9155 - val_y1_output_loss: 3.4849 - val_y2_output_loss: 9.3692 - val_y1_output_root_mean_squared_error: 1.8414 - val_y2_output_root_mean_squared_error: 3.0862
# Epoch 54/500
# 614/614 [==============================] - 0s 125us/sample - loss: 6.3635 - y1_output_loss: 2.0167 - y2_output_loss: 4.2905 - y1_output_root_mean_squared_error: 1.4260 - y2_output_root_mean_squared_error: 2.0809 - val_loss: 7.4864 - val_y1_output_loss: 1.6097 - val_y2_output_loss: 5.6421 - val_y1_output_root_mean_squared_error: 1.2873 - val_y2_output_root_mean_squared_error: 2.4144
# Epoch 55/500
# 614/614 [==============================] - 0s 125us/sample - loss: 6.7467 - y1_output_loss: 2.1290 - y2_output_loss: 4.5592 - y1_output_root_mean_squared_error: 1.4657 - y2_output_root_mean_squared_error: 2.1444 - val_loss: 23.0742 - val_y1_output_loss: 9.0810 - val_y2_output_loss: 15.9608 - val_y1_output_root_mean_squared_error: 2.8875 - val_y2_output_root_mean_squared_error: 3.8389
# Epoch 56/500
# 614/614 [==============================] - 0s 126us/sample - loss: 7.6658 - y1_output_loss: 2.3920 - y2_output_loss: 5.3179 - y1_output_root_mean_squared_error: 1.5428 - y2_output_root_mean_squared_error: 2.2990 - val_loss: 7.7708 - val_y1_output_loss: 2.1206 - val_y2_output_loss: 5.4340 - val_y1_output_root_mean_squared_error: 1.4714 - val_y2_output_root_mean_squared_error: 2.3677
# Epoch 57/500
# 614/614 [==============================] - 0s 125us/sample - loss: 6.2907 - y1_output_loss: 1.9613 - y2_output_loss: 4.2843 - y1_output_root_mean_squared_error: 1.4065 - y2_output_root_mean_squared_error: 2.0766 - val_loss: 10.3484 - val_y1_output_loss: 2.3174 - val_y2_output_loss: 7.9086 - val_y1_output_root_mean_squared_error: 1.5455 - val_y2_output_root_mean_squared_error: 2.8213
# Epoch 58/500
# 614/614 [==============================] - 0s 124us/sample - loss: 5.8490 - y1_output_loss: 1.8355 - y2_output_loss: 4.0569 - y1_output_root_mean_squared_error: 1.3550 - y2_output_root_mean_squared_error: 2.0033 - val_loss: 7.5727 - val_y1_output_loss: 1.8294 - val_y2_output_loss: 5.6695 - val_y1_output_root_mean_squared_error: 1.3471 - val_y2_output_root_mean_squared_error: 2.3996
# Epoch 59/500
# 614/614 [==============================] - 0s 120us/sample - loss: 6.5517 - y1_output_loss: 1.7541 - y2_output_loss: 4.8751 - y1_output_root_mean_squared_error: 1.3238 - y2_output_root_mean_squared_error: 2.1907 - val_loss: 7.6202 - val_y1_output_loss: 1.6403 - val_y2_output_loss: 5.9267 - val_y1_output_root_mean_squared_error: 1.2976 - val_y2_output_root_mean_squared_error: 2.4365
# Epoch 60/500
# 614/614 [==============================] - 0s 119us/sample - loss: 5.7110 - y1_output_loss: 1.6241 - y2_output_loss: 4.1370 - y1_output_root_mean_squared_error: 1.2717 - y2_output_root_mean_squared_error: 2.0233 - val_loss: 6.9719 - val_y1_output_loss: 1.2911 - val_y2_output_loss: 5.4642 - val_y1_output_root_mean_squared_error: 1.1517 - val_y2_output_root_mean_squared_error: 2.3760
# Epoch 61/500
# 614/614 [==============================] - 0s 129us/sample - loss: 6.1441 - y1_output_loss: 1.8172 - y2_output_loss: 4.3126 - y1_output_root_mean_squared_error: 1.3511 - y2_output_root_mean_squared_error: 2.0781 - val_loss: 7.8571 - val_y1_output_loss: 1.2203 - val_y2_output_loss: 6.3768 - val_y1_output_root_mean_squared_error: 1.1186 - val_y2_output_root_mean_squared_error: 2.5702
# Epoch 62/500
# 614/614 [==============================] - 0s 121us/sample - loss: 4.3633 - y1_output_loss: 1.2931 - y2_output_loss: 3.0441 - y1_output_root_mean_squared_error: 1.1390 - y2_output_root_mean_squared_error: 1.7510 - val_loss: 5.4737 - val_y1_output_loss: 1.1644 - val_y2_output_loss: 4.2515 - val_y1_output_root_mean_squared_error: 1.0768 - val_y2_output_root_mean_squared_error: 2.0770
# Epoch 63/500
# 614/614 [==============================] - 0s 120us/sample - loss: 5.2453 - y1_output_loss: 1.3523 - y2_output_loss: 3.8773 - y1_output_root_mean_squared_error: 1.1624 - y2_output_root_mean_squared_error: 1.9733 - val_loss: 12.1152 - val_y1_output_loss: 2.5155 - val_y2_output_loss: 9.2442 - val_y1_output_root_mean_squared_error: 1.6028 - val_y2_output_root_mean_squared_error: 3.0897
# Epoch 64/500
# 614/614 [==============================] - 0s 119us/sample - loss: 6.5834 - y1_output_loss: 1.9006 - y2_output_loss: 4.7347 - y1_output_root_mean_squared_error: 1.3777 - y2_output_root_mean_squared_error: 2.1646 - val_loss: 16.0022 - val_y1_output_loss: 4.7448 - val_y2_output_loss: 11.2667 - val_y1_output_root_mean_squared_error: 2.1471 - val_y2_output_root_mean_squared_error: 3.3752
# Epoch 65/500
# 614/614 [==============================] - 0s 127us/sample - loss: 5.0538 - y1_output_loss: 1.4067 - y2_output_loss: 3.6032 - y1_output_root_mean_squared_error: 1.1914 - y2_output_root_mean_squared_error: 1.9064 - val_loss: 6.7696 - val_y1_output_loss: 1.1033 - val_y2_output_loss: 5.5195 - val_y1_output_root_mean_squared_error: 1.0519 - val_y2_output_root_mean_squared_error: 2.3797
# Epoch 66/500
# 614/614 [==============================] - 0s 119us/sample - loss: 5.8254 - y1_output_loss: 1.6284 - y2_output_loss: 4.2009 - y1_output_root_mean_squared_error: 1.2790 - y2_output_root_mean_squared_error: 2.0468 - val_loss: 9.1975 - val_y1_output_loss: 2.2969 - val_y2_output_loss: 7.0041 - val_y1_output_root_mean_squared_error: 1.5162 - val_y2_output_root_mean_squared_error: 2.6266
# Epoch 67/500
# 614/614 [==============================] - 0s 122us/sample - loss: 5.2271 - y1_output_loss: 1.3676 - y2_output_loss: 3.8459 - y1_output_root_mean_squared_error: 1.1642 - y2_output_root_mean_squared_error: 1.9677 - val_loss: 6.2303 - val_y1_output_loss: 1.2668 - val_y2_output_loss: 4.7603 - val_y1_output_root_mean_squared_error: 1.1426 - val_y2_output_root_mean_squared_error: 2.2192
# Epoch 68/500
# 614/614 [==============================] - 0s 127us/sample - loss: 6.0653 - y1_output_loss: 1.6624 - y2_output_loss: 4.3669 - y1_output_root_mean_squared_error: 1.2939 - y2_output_root_mean_squared_error: 2.0955 - val_loss: 6.0882 - val_y1_output_loss: 1.4984 - val_y2_output_loss: 4.6531 - val_y1_output_root_mean_squared_error: 1.2067 - val_y2_output_root_mean_squared_error: 2.1522
# Epoch 69/500
# 614/614 [==============================] - 0s 136us/sample - loss: 5.6867 - y1_output_loss: 1.5186 - y2_output_loss: 4.2245 - y1_output_root_mean_squared_error: 1.2290 - y2_output_root_mean_squared_error: 2.0436 - val_loss: 12.4473 - val_y1_output_loss: 1.9305 - val_y2_output_loss: 10.1459 - val_y1_output_root_mean_squared_error: 1.4119 - val_y2_output_root_mean_squared_error: 3.2332
# Epoch 70/500
# 614/614 [==============================] - 0s 127us/sample - loss: 6.1993 - y1_output_loss: 1.6091 - y2_output_loss: 4.5459 - y1_output_root_mean_squared_error: 1.2728 - y2_output_root_mean_squared_error: 2.1399 - val_loss: 5.6154 - val_y1_output_loss: 1.0914 - val_y2_output_loss: 4.5183 - val_y1_output_root_mean_squared_error: 1.0496 - val_y2_output_root_mean_squared_error: 2.1246
# Epoch 71/500
# 614/614 [==============================] - 0s 126us/sample - loss: 4.2714 - y1_output_loss: 1.0253 - y2_output_loss: 3.2151 - y1_output_root_mean_squared_error: 1.0152 - y2_output_root_mean_squared_error: 1.8002 - val_loss: 6.6173 - val_y1_output_loss: 1.8610 - val_y2_output_loss: 4.8661 - val_y1_output_root_mean_squared_error: 1.3407 - val_y2_output_root_mean_squared_error: 2.1954
# Epoch 72/500
# 614/614 [==============================] - 0s 121us/sample - loss: 4.6511 - y1_output_loss: 1.1652 - y2_output_loss: 3.5643 - y1_output_root_mean_squared_error: 1.0659 - y2_output_root_mean_squared_error: 1.8748 - val_loss: 12.8702 - val_y1_output_loss: 4.8911 - val_y2_output_loss: 8.1120 - val_y1_output_root_mean_squared_error: 2.2061 - val_y2_output_root_mean_squared_error: 2.8290
# Epoch 73/500
# 614/614 [==============================] - 0s 123us/sample - loss: 4.0390 - y1_output_loss: 1.0423 - y2_output_loss: 3.0081 - y1_output_root_mean_squared_error: 1.0147 - y2_output_root_mean_squared_error: 1.7348 - val_loss: 11.2587 - val_y1_output_loss: 4.0069 - val_y2_output_loss: 7.5762 - val_y1_output_root_mean_squared_error: 1.9364 - val_y2_output_root_mean_squared_error: 2.7403
# Epoch 74/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.3148 - y1_output_loss: 1.1657 - y2_output_loss: 3.1264 - y1_output_root_mean_squared_error: 1.0843 - y2_output_root_mean_squared_error: 1.7718 - val_loss: 4.4648 - val_y1_output_loss: 0.7765 - val_y2_output_loss: 3.5730 - val_y1_output_root_mean_squared_error: 0.8896 - val_y2_output_root_mean_squared_error: 1.9166
# Epoch 75/500
# 614/614 [==============================] - 0s 120us/sample - loss: 9.4617 - y1_output_loss: 2.8659 - y2_output_loss: 6.5654 - y1_output_root_mean_squared_error: 1.6940 - y2_output_root_mean_squared_error: 2.5675 - val_loss: 4.5393 - val_y1_output_loss: 0.8378 - val_y2_output_loss: 3.6566 - val_y1_output_root_mean_squared_error: 0.9233 - val_y2_output_root_mean_squared_error: 1.9201
# Epoch 76/500
# 614/614 [==============================] - 0s 126us/sample - loss: 4.1688 - y1_output_loss: 1.0952 - y2_output_loss: 3.0359 - y1_output_root_mean_squared_error: 1.0513 - y2_output_root_mean_squared_error: 1.7503 - val_loss: 5.3493 - val_y1_output_loss: 1.1186 - val_y2_output_loss: 4.1812 - val_y1_output_root_mean_squared_error: 1.0441 - val_y2_output_root_mean_squared_error: 2.0638
# Epoch 77/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.4035 - y1_output_loss: 0.7449 - y2_output_loss: 2.7276 - y1_output_root_mean_squared_error: 0.8602 - y2_output_root_mean_squared_error: 1.6321 - val_loss: 13.7082 - val_y1_output_loss: 2.8230 - val_y2_output_loss: 11.5033 - val_y1_output_root_mean_squared_error: 1.6492 - val_y2_output_root_mean_squared_error: 3.3149
# Epoch 78/500
# 614/614 [==============================] - 0s 120us/sample - loss: 4.0327 - y1_output_loss: 0.8503 - y2_output_loss: 3.1518 - y1_output_root_mean_squared_error: 0.9250 - y2_output_root_mean_squared_error: 1.7824 - val_loss: 6.5855 - val_y1_output_loss: 1.2723 - val_y2_output_loss: 5.0972 - val_y1_output_root_mean_squared_error: 1.1408 - val_y2_output_root_mean_squared_error: 2.2987
# Epoch 79/500
# 614/614 [==============================] - 0s 120us/sample - loss: 4.1589 - y1_output_loss: 1.0516 - y2_output_loss: 3.1090 - y1_output_root_mean_squared_error: 1.0200 - y2_output_root_mean_squared_error: 1.7659 - val_loss: 5.7503 - val_y1_output_loss: 0.7856 - val_y2_output_loss: 4.7701 - val_y1_output_root_mean_squared_error: 0.9011 - val_y2_output_root_mean_squared_error: 2.2222
# Epoch 80/500
# 614/614 [==============================] - 0s 121us/sample - loss: 4.2706 - y1_output_loss: 1.0368 - y2_output_loss: 3.2282 - y1_output_root_mean_squared_error: 1.0219 - y2_output_root_mean_squared_error: 1.7962 - val_loss: 4.6930 - val_y1_output_loss: 1.1869 - val_y2_output_loss: 3.4505 - val_y1_output_root_mean_squared_error: 1.0948 - val_y2_output_root_mean_squared_error: 1.8693
# Epoch 81/500
# 614/614 [==============================] - 0s 120us/sample - loss: 3.4476 - y1_output_loss: 0.8012 - y2_output_loss: 2.7281 - y1_output_root_mean_squared_error: 0.8985 - y2_output_root_mean_squared_error: 1.6249 - val_loss: 18.9551 - val_y1_output_loss: 2.9346 - val_y2_output_loss: 16.4436 - val_y1_output_root_mean_squared_error: 1.6425 - val_y2_output_root_mean_squared_error: 4.0320
# Epoch 82/500
# 614/614 [==============================] - 0s 119us/sample - loss: 4.2051 - y1_output_loss: 0.9921 - y2_output_loss: 3.1791 - y1_output_root_mean_squared_error: 1.0008 - y2_output_root_mean_squared_error: 1.7898 - val_loss: 4.2762 - val_y1_output_loss: 0.6812 - val_y2_output_loss: 3.5214 - val_y1_output_root_mean_squared_error: 0.8294 - val_y2_output_root_mean_squared_error: 1.8943
# Epoch 83/500
# 614/614 [==============================] - 0s 120us/sample - loss: 3.4560 - y1_output_loss: 0.8462 - y2_output_loss: 2.6098 - y1_output_root_mean_squared_error: 0.9135 - y2_output_root_mean_squared_error: 1.6191 - val_loss: 4.1457 - val_y1_output_loss: 0.8577 - val_y2_output_loss: 3.1829 - val_y1_output_root_mean_squared_error: 0.9341 - val_y2_output_root_mean_squared_error: 1.8092
# Epoch 84/500
# 614/614 [==============================] - 0s 120us/sample - loss: 3.6912 - y1_output_loss: 0.7916 - y2_output_loss: 2.8714 - y1_output_root_mean_squared_error: 0.8936 - y2_output_root_mean_squared_error: 1.7008 - val_loss: 4.2505 - val_y1_output_loss: 0.6158 - val_y2_output_loss: 3.4967 - val_y1_output_root_mean_squared_error: 0.7900 - val_y2_output_root_mean_squared_error: 1.9043
# Epoch 85/500
# 614/614 [==============================] - 0s 124us/sample - loss: 4.5607 - y1_output_loss: 1.1978 - y2_output_loss: 3.3426 - y1_output_root_mean_squared_error: 1.0955 - y2_output_root_mean_squared_error: 1.8332 - val_loss: 6.6460 - val_y1_output_loss: 2.1809 - val_y2_output_loss: 4.7340 - val_y1_output_root_mean_squared_error: 1.4366 - val_y2_output_root_mean_squared_error: 2.1406
# Epoch 86/500
# 614/614 [==============================] - 0s 122us/sample - loss: 6.3766 - y1_output_loss: 1.8017 - y2_output_loss: 4.6289 - y1_output_root_mean_squared_error: 1.3418 - y2_output_root_mean_squared_error: 2.1392 - val_loss: 7.0204 - val_y1_output_loss: 1.4439 - val_y2_output_loss: 5.8491 - val_y1_output_root_mean_squared_error: 1.1886 - val_y2_output_root_mean_squared_error: 2.3680
# Epoch 87/500
# 614/614 [==============================] - 0s 123us/sample - loss: 3.7589 - y1_output_loss: 0.7531 - y2_output_loss: 2.9736 - y1_output_root_mean_squared_error: 0.8704 - y2_output_root_mean_squared_error: 1.7324 - val_loss: 4.1927 - val_y1_output_loss: 0.6769 - val_y2_output_loss: 3.3926 - val_y1_output_root_mean_squared_error: 0.8363 - val_y2_output_root_mean_squared_error: 1.8690
# Epoch 88/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.0209 - y1_output_loss: 0.6041 - y2_output_loss: 2.4020 - y1_output_root_mean_squared_error: 0.7790 - y2_output_root_mean_squared_error: 1.5537 - val_loss: 7.1980 - val_y1_output_loss: 1.8762 - val_y2_output_loss: 5.6046 - val_y1_output_root_mean_squared_error: 1.3500 - val_y2_output_root_mean_squared_error: 2.3185
# Epoch 89/500
# 614/614 [==============================] - 0s 120us/sample - loss: 5.1440 - y1_output_loss: 1.4024 - y2_output_loss: 3.7293 - y1_output_root_mean_squared_error: 1.1856 - y2_output_root_mean_squared_error: 1.9335 - val_loss: 5.8467 - val_y1_output_loss: 0.5548 - val_y2_output_loss: 5.0937 - val_y1_output_root_mean_squared_error: 0.7570 - val_y2_output_root_mean_squared_error: 2.2965
# Epoch 90/500
# 614/614 [==============================] - 0s 121us/sample - loss: 2.7300 - y1_output_loss: 0.5032 - y2_output_loss: 2.2544 - y1_output_root_mean_squared_error: 0.7098 - y2_output_root_mean_squared_error: 1.4921 - val_loss: 3.9251 - val_y1_output_loss: 0.6374 - val_y2_output_loss: 3.1792 - val_y1_output_root_mean_squared_error: 0.7987 - val_y2_output_root_mean_squared_error: 1.8131
# Epoch 91/500
# 614/614 [==============================] - 0s 120us/sample - loss: 2.6577 - y1_output_loss: 0.5619 - y2_output_loss: 2.0748 - y1_output_root_mean_squared_error: 0.7517 - y2_output_root_mean_squared_error: 1.4466 - val_loss: 3.7421 - val_y1_output_loss: 0.5483 - val_y2_output_loss: 3.0758 - val_y1_output_root_mean_squared_error: 0.7446 - val_y2_output_root_mean_squared_error: 1.7854
# Epoch 92/500
# 614/614 [==============================] - 0s 120us/sample - loss: 2.7674 - y1_output_loss: 0.6032 - y2_output_loss: 2.1526 - y1_output_root_mean_squared_error: 0.7716 - y2_output_root_mean_squared_error: 1.4738 - val_loss: 4.3626 - val_y1_output_loss: 1.0337 - val_y2_output_loss: 3.2185 - val_y1_output_root_mean_squared_error: 1.0271 - val_y2_output_root_mean_squared_error: 1.8187
# Epoch 93/500
# 614/614 [==============================] - 0s 118us/sample - loss: 4.9422 - y1_output_loss: 1.1879 - y2_output_loss: 3.7267 - y1_output_root_mean_squared_error: 1.0928 - y2_output_root_mean_squared_error: 1.9360 - val_loss: 6.2124 - val_y1_output_loss: 1.4991 - val_y2_output_loss: 4.8521 - val_y1_output_root_mean_squared_error: 1.1837 - val_y2_output_root_mean_squared_error: 2.1935
# Epoch 94/500
# 614/614 [==============================] - 0s 118us/sample - loss: 2.8526 - y1_output_loss: 0.6064 - y2_output_loss: 2.2568 - y1_output_root_mean_squared_error: 0.7785 - y2_output_root_mean_squared_error: 1.4988 - val_loss: 4.2654 - val_y1_output_loss: 0.8205 - val_y2_output_loss: 3.3998 - val_y1_output_root_mean_squared_error: 0.9175 - val_y2_output_root_mean_squared_error: 1.8503
# Epoch 95/500
# 614/614 [==============================] - 0s 118us/sample - loss: 4.2037 - y1_output_loss: 0.9661 - y2_output_loss: 3.2281 - y1_output_root_mean_squared_error: 0.9871 - y2_output_root_mean_squared_error: 1.7970 - val_loss: 4.2992 - val_y1_output_loss: 0.9318 - val_y2_output_loss: 3.3593 - val_y1_output_root_mean_squared_error: 0.9694 - val_y2_output_root_mean_squared_error: 1.8329
# Epoch 96/500
# 614/614 [==============================] - 0s 119us/sample - loss: 3.2637 - y1_output_loss: 0.6991 - y2_output_loss: 2.5366 - y1_output_root_mean_squared_error: 0.8397 - y2_output_root_mean_squared_error: 1.5996 - val_loss: 4.1796 - val_y1_output_loss: 0.9683 - val_y2_output_loss: 3.1674 - val_y1_output_root_mean_squared_error: 0.9884 - val_y2_output_root_mean_squared_error: 1.7896
# Epoch 97/500
# 614/614 [==============================] - 0s 119us/sample - loss: 2.9881 - y1_output_loss: 0.6611 - y2_output_loss: 2.3318 - y1_output_root_mean_squared_error: 0.8163 - y2_output_root_mean_squared_error: 1.5237 - val_loss: 5.0621 - val_y1_output_loss: 0.5663 - val_y2_output_loss: 4.3878 - val_y1_output_root_mean_squared_error: 0.7491 - val_y2_output_root_mean_squared_error: 2.1216
# Epoch 98/500
# 614/614 [==============================] - 0s 121us/sample - loss: 3.1444 - y1_output_loss: 0.7450 - y2_output_loss: 2.3846 - y1_output_root_mean_squared_error: 0.8624 - y2_output_root_mean_squared_error: 1.5494 - val_loss: 3.9908 - val_y1_output_loss: 0.9692 - val_y2_output_loss: 3.0545 - val_y1_output_root_mean_squared_error: 0.9867 - val_y2_output_root_mean_squared_error: 1.7370
# Epoch 99/500
# 614/614 [==============================] - 0s 122us/sample - loss: 3.1271 - y1_output_loss: 0.6091 - y2_output_loss: 2.5112 - y1_output_root_mean_squared_error: 0.7827 - y2_output_root_mean_squared_error: 1.5857 - val_loss: 6.1548 - val_y1_output_loss: 0.7365 - val_y2_output_loss: 5.2933 - val_y1_output_root_mean_squared_error: 0.8571 - val_y2_output_root_mean_squared_error: 2.3281
# Epoch 100/500
# 614/614 [==============================] - 0s 122us/sample - loss: 3.0977 - y1_output_loss: 0.6474 - y2_output_loss: 2.4370 - y1_output_root_mean_squared_error: 0.8005 - y2_output_root_mean_squared_error: 1.5675 - val_loss: 3.8301 - val_y1_output_loss: 0.6023 - val_y2_output_loss: 3.1043 - val_y1_output_root_mean_squared_error: 0.7859 - val_y2_output_root_mean_squared_error: 1.7923
# Epoch 101/500
# 614/614 [==============================] - 0s 120us/sample - loss: 2.7584 - y1_output_loss: 0.5682 - y2_output_loss: 2.1772 - y1_output_root_mean_squared_error: 0.7547 - y2_output_root_mean_squared_error: 1.4795 - val_loss: 5.6382 - val_y1_output_loss: 1.9419 - val_y2_output_loss: 3.7136 - val_y1_output_root_mean_squared_error: 1.3947 - val_y2_output_root_mean_squared_error: 1.9218
# Epoch 102/500
# 614/614 [==============================] - 0s 121us/sample - loss: 2.9513 - y1_output_loss: 0.6391 - y2_output_loss: 2.3486 - y1_output_root_mean_squared_error: 0.7807 - y2_output_root_mean_squared_error: 1.5303 - val_loss: 6.8209 - val_y1_output_loss: 1.9630 - val_y2_output_loss: 5.1368 - val_y1_output_root_mean_squared_error: 1.3796 - val_y2_output_root_mean_squared_error: 2.2175
# Epoch 103/500
# 614/614 [==============================] - 0s 121us/sample - loss: 4.1884 - y1_output_loss: 1.0600 - y2_output_loss: 3.0915 - y1_output_root_mean_squared_error: 1.0338 - y2_output_root_mean_squared_error: 1.7663 - val_loss: 3.5047 - val_y1_output_loss: 0.6540 - val_y2_output_loss: 2.7918 - val_y1_output_root_mean_squared_error: 0.8162 - val_y2_output_root_mean_squared_error: 1.6848
# Epoch 104/500
# 614/614 [==============================] - 0s 120us/sample - loss: 2.4192 - y1_output_loss: 0.4908 - y2_output_loss: 1.9311 - y1_output_root_mean_squared_error: 0.6971 - y2_output_root_mean_squared_error: 1.3904 - val_loss: 3.9995 - val_y1_output_loss: 0.7671 - val_y2_output_loss: 3.2612 - val_y1_output_root_mean_squared_error: 0.8786 - val_y2_output_root_mean_squared_error: 1.7966
# Epoch 105/500
# 614/614 [==============================] - 0s 121us/sample - loss: 3.7149 - y1_output_loss: 0.7596 - y2_output_loss: 3.0182 - y1_output_root_mean_squared_error: 0.8503 - y2_output_root_mean_squared_error: 1.7297 - val_loss: 11.1395 - val_y1_output_loss: 4.3494 - val_y2_output_loss: 6.7320 - val_y1_output_root_mean_squared_error: 2.0881 - val_y2_output_root_mean_squared_error: 2.6037
# Epoch 106/500
# 614/614 [==============================] - 0s 121us/sample - loss: 4.6477 - y1_output_loss: 1.2483 - y2_output_loss: 3.3805 - y1_output_root_mean_squared_error: 1.1184 - y2_output_root_mean_squared_error: 1.8431 - val_loss: 6.4900 - val_y1_output_loss: 0.8083 - val_y2_output_loss: 5.5131 - val_y1_output_root_mean_squared_error: 0.9030 - val_y2_output_root_mean_squared_error: 2.3821
# Epoch 107/500
# 614/614 [==============================] - 0s 120us/sample - loss: 3.0265 - y1_output_loss: 0.7205 - y2_output_loss: 2.3162 - y1_output_root_mean_squared_error: 0.8505 - y2_output_root_mean_squared_error: 1.5176 - val_loss: 3.4969 - val_y1_output_loss: 0.5212 - val_y2_output_loss: 2.9360 - val_y1_output_root_mean_squared_error: 0.7315 - val_y2_output_root_mean_squared_error: 1.7210
# Epoch 108/500
# 614/614 [==============================] - 0s 121us/sample - loss: 2.5317 - y1_output_loss: 0.5302 - y2_output_loss: 2.0371 - y1_output_root_mean_squared_error: 0.7210 - y2_output_root_mean_squared_error: 1.4184 - val_loss: 13.6994 - val_y1_output_loss: 4.2261 - val_y2_output_loss: 9.8669 - val_y1_output_root_mean_squared_error: 1.9914 - val_y2_output_root_mean_squared_error: 3.1199
# Epoch 109/500
# 614/614 [==============================] - 0s 119us/sample - loss: 3.3565 - y1_output_loss: 0.6053 - y2_output_loss: 2.7300 - y1_output_root_mean_squared_error: 0.7815 - y2_output_root_mean_squared_error: 1.6570 - val_loss: 3.3829 - val_y1_output_loss: 0.6040 - val_y2_output_loss: 2.7002 - val_y1_output_root_mean_squared_error: 0.7855 - val_y2_output_root_mean_squared_error: 1.6631
# Epoch 110/500
# 614/614 [==============================] - 0s 121us/sample - loss: 2.3772 - y1_output_loss: 0.4686 - y2_output_loss: 1.9199 - y1_output_root_mean_squared_error: 0.6846 - y2_output_root_mean_squared_error: 1.3815 - val_loss: 7.9844 - val_y1_output_loss: 0.8134 - val_y2_output_loss: 6.9332 - val_y1_output_root_mean_squared_error: 0.9102 - val_y2_output_root_mean_squared_error: 2.6751
# Epoch 111/500
# 614/614 [==============================] - 0s 119us/sample - loss: 2.8876 - y1_output_loss: 0.5876 - y2_output_loss: 2.3013 - y1_output_root_mean_squared_error: 0.7677 - y2_output_root_mean_squared_error: 1.5160 - val_loss: 4.3833 - val_y1_output_loss: 0.6406 - val_y2_output_loss: 3.6205 - val_y1_output_root_mean_squared_error: 0.8038 - val_y2_output_root_mean_squared_error: 1.9332
# Epoch 112/500
# 614/614 [==============================] - 0s 119us/sample - loss: 2.5304 - y1_output_loss: 0.5798 - y2_output_loss: 1.9334 - y1_output_root_mean_squared_error: 0.7627 - y2_output_root_mean_squared_error: 1.3960 - val_loss: 3.0836 - val_y1_output_loss: 0.5390 - val_y2_output_loss: 2.4766 - val_y1_output_root_mean_squared_error: 0.7413 - val_y2_output_root_mean_squared_error: 1.5919
# Epoch 113/500
# 614/614 [==============================] - 0s 121us/sample - loss: 3.1419 - y1_output_loss: 0.6677 - y2_output_loss: 2.4668 - y1_output_root_mean_squared_error: 0.8191 - y2_output_root_mean_squared_error: 1.5720 - val_loss: 5.3705 - val_y1_output_loss: 0.8423 - val_y2_output_loss: 4.5545 - val_y1_output_root_mean_squared_error: 0.8795 - val_y2_output_root_mean_squared_error: 2.1441
# Epoch 114/500
# 614/614 [==============================] - 0s 119us/sample - loss: 2.4328 - y1_output_loss: 0.5169 - y2_output_loss: 1.8986 - y1_output_root_mean_squared_error: 0.7208 - y2_output_root_mean_squared_error: 1.3832 - val_loss: 4.2018 - val_y1_output_loss: 0.5750 - val_y2_output_loss: 3.5269 - val_y1_output_root_mean_squared_error: 0.7546 - val_y2_output_root_mean_squared_error: 1.9059
# Epoch 115/500
# 614/614 [==============================] - 0s 118us/sample - loss: 2.4446 - y1_output_loss: 0.4597 - y2_output_loss: 1.9777 - y1_output_root_mean_squared_error: 0.6770 - y2_output_root_mean_squared_error: 1.4094 - val_loss: 2.9138 - val_y1_output_loss: 0.5567 - val_y2_output_loss: 2.3023 - val_y1_output_root_mean_squared_error: 0.7351 - val_y2_output_root_mean_squared_error: 1.5406
# Epoch 116/500
# 614/614 [==============================] - 0s 118us/sample - loss: 2.8774 - y1_output_loss: 0.6566 - y2_output_loss: 2.2059 - y1_output_root_mean_squared_error: 0.8105 - y2_output_root_mean_squared_error: 1.4902 - val_loss: 5.0972 - val_y1_output_loss: 1.0670 - val_y2_output_loss: 4.0616 - val_y1_output_root_mean_squared_error: 0.9913 - val_y2_output_root_mean_squared_error: 2.0284
# Epoch 117/500
# 614/614 [==============================] - 0s 118us/sample - loss: 2.6419 - y1_output_loss: 0.5632 - y2_output_loss: 2.0716 - y1_output_root_mean_squared_error: 0.7529 - y2_output_root_mean_squared_error: 1.4405 - val_loss: 3.3400 - val_y1_output_loss: 0.5450 - val_y2_output_loss: 2.7047 - val_y1_output_root_mean_squared_error: 0.7453 - val_y2_output_root_mean_squared_error: 1.6687
# Epoch 118/500
# 614/614 [==============================] - 0s 121us/sample - loss: 5.7436 - y1_output_loss: 1.7069 - y2_output_loss: 4.0845 - y1_output_root_mean_squared_error: 1.2962 - y2_output_root_mean_squared_error: 2.0158 - val_loss: 10.6856 - val_y1_output_loss: 2.7770 - val_y2_output_loss: 7.7539 - val_y1_output_root_mean_squared_error: 1.6648 - val_y2_output_root_mean_squared_error: 2.8132
# Epoch 119/500
# 614/614 [==============================] - 0s 120us/sample - loss: 2.7633 - y1_output_loss: 0.6281 - y2_output_loss: 2.1265 - y1_output_root_mean_squared_error: 0.7951 - y2_output_root_mean_squared_error: 1.4598 - val_loss: 5.2627 - val_y1_output_loss: 0.8501 - val_y2_output_loss: 4.3876 - val_y1_output_root_mean_squared_error: 0.9056 - val_y2_output_root_mean_squared_error: 2.1078
# Epoch 120/500
# 614/614 [==============================] - 0s 119us/sample - loss: 2.8969 - y1_output_loss: 0.5877 - y2_output_loss: 2.2881 - y1_output_root_mean_squared_error: 0.7674 - y2_output_root_mean_squared_error: 1.5192 - val_loss: 4.3317 - val_y1_output_loss: 0.8334 - val_y2_output_loss: 3.4399 - val_y1_output_root_mean_squared_error: 0.8959 - val_y2_output_root_mean_squared_error: 1.8786
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4316 - y1_output_loss: 0.1105 - y2_output_loss: 0.3186 - y1_output_root_mean_squared_error: 0.3333 - y2_output_root_mean_squared_error: 0.5662 - val_loss: 0.9542 - val_y1_output_loss: 0.2123 - val_y2_output_loss: 0.7261 - val_y1_output_root_mean_squared_error: 0.4602 - val_y2_output_root_mean_squared_error: 0.8617
# Epoch 462/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.7086 - y1_output_loss: 0.1360 - y2_output_loss: 0.5701 - y1_output_root_mean_squared_error: 0.3702 - y2_output_root_mean_squared_error: 0.7560 - val_loss: 1.0366 - val_y1_output_loss: 0.2030 - val_y2_output_loss: 0.8125 - val_y1_output_root_mean_squared_error: 0.4499 - val_y2_output_root_mean_squared_error: 0.9134
# Epoch 463/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.5366 - y1_output_loss: 0.1319 - y2_output_loss: 0.4188 - y1_output_root_mean_squared_error: 0.3622 - y2_output_root_mean_squared_error: 0.6368 - val_loss: 4.9570 - val_y1_output_loss: 0.6211 - val_y2_output_loss: 4.4362 - val_y1_output_root_mean_squared_error: 0.7537 - val_y2_output_root_mean_squared_error: 2.0950
# Epoch 464/500
# 614/614 [==============================] - 0s 121us/sample - loss: 0.5765 - y1_output_loss: 0.1298 - y2_output_loss: 0.4447 - y1_output_root_mean_squared_error: 0.3620 - y2_output_root_mean_squared_error: 0.6674 - val_loss: 1.7956 - val_y1_output_loss: 0.2071 - val_y2_output_loss: 1.5625 - val_y1_output_root_mean_squared_error: 0.4528 - val_y2_output_root_mean_squared_error: 1.2612
# Epoch 465/500
# 614/614 [==============================] - 0s 120us/sample - loss: 0.5013 - y1_output_loss: 0.1151 - y2_output_loss: 0.3859 - y1_output_root_mean_squared_error: 0.3402 - y2_output_root_mean_squared_error: 0.6210 - val_loss: 0.9942 - val_y1_output_loss: 0.2402 - val_y2_output_loss: 0.7559 - val_y1_output_root_mean_squared_error: 0.4974 - val_y2_output_root_mean_squared_error: 0.8642
# Epoch 466/500
# 614/614 [==============================] - 0s 122us/sample - loss: 0.4544 - y1_output_loss: 0.1088 - y2_output_loss: 0.3446 - y1_output_root_mean_squared_error: 0.3283 - y2_output_root_mean_squared_error: 0.5888 - val_loss: 0.9959 - val_y1_output_loss: 0.3714 - val_y2_output_loss: 0.6156 - val_y1_output_root_mean_squared_error: 0.6098 - val_y2_output_root_mean_squared_error: 0.7899
# Epoch 467/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.4270 - y1_output_loss: 0.1215 - y2_output_loss: 0.3025 - y1_output_root_mean_squared_error: 0.3500 - y2_output_root_mean_squared_error: 0.5519 - val_loss: 0.9486 - val_y1_output_loss: 0.2413 - val_y2_output_loss: 0.7162 - val_y1_output_root_mean_squared_error: 0.4959 - val_y2_output_root_mean_squared_error: 0.8383
# Epoch 468/500
# 614/614 [==============================] - 0s 122us/sample - loss: 0.4187 - y1_output_loss: 0.1245 - y2_output_loss: 0.2976 - y1_output_root_mean_squared_error: 0.3460 - y2_output_root_mean_squared_error: 0.5468 - val_loss: 1.1698 - val_y1_output_loss: 0.4496 - val_y2_output_loss: 0.7083 - val_y1_output_root_mean_squared_error: 0.6691 - val_y2_output_root_mean_squared_error: 0.8498
# Epoch 469/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.7016 - y1_output_loss: 0.1700 - y2_output_loss: 0.5272 - y1_output_root_mean_squared_error: 0.4134 - y2_output_root_mean_squared_error: 0.7285 - val_loss: 0.8588 - val_y1_output_loss: 0.2226 - val_y2_output_loss: 0.6232 - val_y1_output_root_mean_squared_error: 0.4782 - val_y2_output_root_mean_squared_error: 0.7938
# Epoch 470/500
# 614/614 [==============================] - 0s 120us/sample - loss: 0.4107 - y1_output_loss: 0.0967 - y2_output_loss: 0.3105 - y1_output_root_mean_squared_error: 0.3120 - y2_output_root_mean_squared_error: 0.5598 - val_loss: 0.9512 - val_y1_output_loss: 0.2494 - val_y2_output_loss: 0.6950 - val_y1_output_root_mean_squared_error: 0.5029 - val_y2_output_root_mean_squared_error: 0.8357
# Epoch 471/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.6233 - y1_output_loss: 0.1248 - y2_output_loss: 0.4953 - y1_output_root_mean_squared_error: 0.3532 - y2_output_root_mean_squared_error: 0.7060 - val_loss: 0.8604 - val_y1_output_loss: 0.2484 - val_y2_output_loss: 0.6215 - val_y1_output_root_mean_squared_error: 0.4870 - val_y2_output_root_mean_squared_error: 0.7895
# Epoch 472/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.5060 - y1_output_loss: 0.1103 - y2_output_loss: 0.3915 - y1_output_root_mean_squared_error: 0.3336 - y2_output_root_mean_squared_error: 0.6283 - val_loss: 0.8862 - val_y1_output_loss: 0.2749 - val_y2_output_loss: 0.6426 - val_y1_output_root_mean_squared_error: 0.5015 - val_y2_output_root_mean_squared_error: 0.7967
# Epoch 473/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3867 - y1_output_loss: 0.0937 - y2_output_loss: 0.2929 - y1_output_root_mean_squared_error: 0.3061 - y2_output_root_mean_squared_error: 0.5413 - val_loss: 0.9820 - val_y1_output_loss: 0.2441 - val_y2_output_loss: 0.7074 - val_y1_output_root_mean_squared_error: 0.5006 - val_y2_output_root_mean_squared_error: 0.8552
# Epoch 474/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4039 - y1_output_loss: 0.1089 - y2_output_loss: 0.2936 - y1_output_root_mean_squared_error: 0.3299 - y2_output_root_mean_squared_error: 0.5432 - val_loss: 0.8298 - val_y1_output_loss: 0.2291 - val_y2_output_loss: 0.5820 - val_y1_output_root_mean_squared_error: 0.4774 - val_y2_output_root_mean_squared_error: 0.7758
# Epoch 475/500
# 614/614 [==============================] - 0s 120us/sample - loss: 0.6594 - y1_output_loss: 0.1457 - y2_output_loss: 0.5097 - y1_output_root_mean_squared_error: 0.3826 - y2_output_root_mean_squared_error: 0.7162 - val_loss: 0.8857 - val_y1_output_loss: 0.2609 - val_y2_output_loss: 0.6152 - val_y1_output_root_mean_squared_error: 0.5114 - val_y2_output_root_mean_squared_error: 0.7900
# Epoch 476/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.6868 - y1_output_loss: 0.1643 - y2_output_loss: 0.5284 - y1_output_root_mean_squared_error: 0.3980 - y2_output_root_mean_squared_error: 0.7269 - val_loss: 1.8054 - val_y1_output_loss: 0.4055 - val_y2_output_loss: 1.3521 - val_y1_output_root_mean_squared_error: 0.6407 - val_y2_output_root_mean_squared_error: 1.1811
# Epoch 477/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.5313 - y1_output_loss: 0.1354 - y2_output_loss: 0.3915 - y1_output_root_mean_squared_error: 0.3697 - y2_output_root_mean_squared_error: 0.6282 - val_loss: 0.7894 - val_y1_output_loss: 0.1994 - val_y2_output_loss: 0.5932 - val_y1_output_root_mean_squared_error: 0.4464 - val_y2_output_root_mean_squared_error: 0.7682
# Epoch 478/500
# 614/614 [==============================] - 0s 120us/sample - loss: 0.4783 - y1_output_loss: 0.1128 - y2_output_loss: 0.3619 - y1_output_root_mean_squared_error: 0.3370 - y2_output_root_mean_squared_error: 0.6039 - val_loss: 0.8252 - val_y1_output_loss: 0.2410 - val_y2_output_loss: 0.5937 - val_y1_output_root_mean_squared_error: 0.4747 - val_y2_output_root_mean_squared_error: 0.7745
# Epoch 479/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.4600 - y1_output_loss: 0.1146 - y2_output_loss: 0.3429 - y1_output_root_mean_squared_error: 0.3387 - y2_output_root_mean_squared_error: 0.5876 - val_loss: 0.7988 - val_y1_output_loss: 0.2010 - val_y2_output_loss: 0.5865 - val_y1_output_root_mean_squared_error: 0.4478 - val_y2_output_root_mean_squared_error: 0.7735
# Epoch 480/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.4702 - y1_output_loss: 0.1080 - y2_output_loss: 0.3632 - y1_output_root_mean_squared_error: 0.3276 - y2_output_root_mean_squared_error: 0.6024 - val_loss: 1.0318 - val_y1_output_loss: 0.2454 - val_y2_output_loss: 0.8000 - val_y1_output_root_mean_squared_error: 0.4855 - val_y2_output_root_mean_squared_error: 0.8922
# Epoch 481/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.6103 - y1_output_loss: 0.1452 - y2_output_loss: 0.4618 - y1_output_root_mean_squared_error: 0.3827 - y2_output_root_mean_squared_error: 0.6811 - val_loss: 0.8893 - val_y1_output_loss: 0.2200 - val_y2_output_loss: 0.6540 - val_y1_output_root_mean_squared_error: 0.4740 - val_y2_output_root_mean_squared_error: 0.8152
# Epoch 482/500
# 614/614 [==============================] - 0s 119us/sample - loss: 0.5442 - y1_output_loss: 0.1143 - y2_output_loss: 0.4256 - y1_output_root_mean_squared_error: 0.3396 - y2_output_root_mean_squared_error: 0.6549 - val_loss: 0.9147 - val_y1_output_loss: 0.2349 - val_y2_output_loss: 0.6849 - val_y1_output_root_mean_squared_error: 0.4737 - val_y2_output_root_mean_squared_error: 0.8308
# Epoch 483/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4913 - y1_output_loss: 0.1166 - y2_output_loss: 0.3721 - y1_output_root_mean_squared_error: 0.3414 - y2_output_root_mean_squared_error: 0.6121 - val_loss: 1.0414 - val_y1_output_loss: 0.2778 - val_y2_output_loss: 0.7740 - val_y1_output_root_mean_squared_error: 0.5184 - val_y2_output_root_mean_squared_error: 0.8790
# Epoch 484/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.5146 - y1_output_loss: 0.1281 - y2_output_loss: 0.3880 - y1_output_root_mean_squared_error: 0.3581 - y2_output_root_mean_squared_error: 0.6216 - val_loss: 1.8954 - val_y1_output_loss: 0.4280 - val_y2_output_loss: 1.5226 - val_y1_output_root_mean_squared_error: 0.6521 - val_y2_output_root_mean_squared_error: 1.2125
# Epoch 485/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.4793 - y1_output_loss: 0.1209 - y2_output_loss: 0.3569 - y1_output_root_mean_squared_error: 0.3469 - y2_output_root_mean_squared_error: 0.5991 - val_loss: 0.8491 - val_y1_output_loss: 0.2573 - val_y2_output_loss: 0.5711 - val_y1_output_root_mean_squared_error: 0.5120 - val_y2_output_root_mean_squared_error: 0.7662
# Epoch 486/500
# 614/614 [==============================] - 0s 117us/sample - loss: 0.4341 - y1_output_loss: 0.1229 - y2_output_loss: 0.3079 - y1_output_root_mean_squared_error: 0.3518 - y2_output_root_mean_squared_error: 0.5571 - val_loss: 0.8020 - val_y1_output_loss: 0.2044 - val_y2_output_loss: 0.5752 - val_y1_output_root_mean_squared_error: 0.4560 - val_y2_output_root_mean_squared_error: 0.7708
# Epoch 487/500
# 614/614 [==============================] - 0s 119us/sample - loss: 0.4737 - y1_output_loss: 0.1112 - y2_output_loss: 0.3590 - y1_output_root_mean_squared_error: 0.3351 - y2_output_root_mean_squared_error: 0.6012 - val_loss: 0.8586 - val_y1_output_loss: 0.2492 - val_y2_output_loss: 0.6006 - val_y1_output_root_mean_squared_error: 0.5011 - val_y2_output_root_mean_squared_error: 0.7794
# Epoch 488/500
# 614/614 [==============================] - 0s 122us/sample - loss: 0.4022 - y1_output_loss: 0.0985 - y2_output_loss: 0.3072 - y1_output_root_mean_squared_error: 0.3135 - y2_output_root_mean_squared_error: 0.5513 - val_loss: 2.2789 - val_y1_output_loss: 0.5887 - val_y2_output_loss: 1.8178 - val_y1_output_root_mean_squared_error: 0.7222 - val_y2_output_root_mean_squared_error: 1.3256
# Epoch 489/500
# 614/614 [==============================] - 0s 118us/sample - loss: 0.8072 - y1_output_loss: 0.1974 - y2_output_loss: 0.6096 - y1_output_root_mean_squared_error: 0.4441 - y2_output_root_mean_squared_error: 0.7810 - val_loss: 0.9527 - val_y1_output_loss: 0.2101 - val_y2_output_loss: 0.7573 - val_y1_output_root_mean_squared_error: 0.4523 - val_y2_output_root_mean_squared_error: 0.8649
# Epoch 490/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.4029 - y1_output_loss: 0.1048 - y2_output_loss: 0.2984 - y1_output_root_mean_squared_error: 0.3243 - y2_output_root_mean_squared_error: 0.5456 - val_loss: 1.3576 - val_y1_output_loss: 0.2062 - val_y2_output_loss: 1.1499 - val_y1_output_root_mean_squared_error: 0.4491 - val_y2_output_root_mean_squared_error: 1.0751
# Epoch 491/500
# 614/614 [==============================] - 0s 120us/sample - loss: 0.4475 - y1_output_loss: 0.1198 - y2_output_loss: 0.3279 - y1_output_root_mean_squared_error: 0.3467 - y2_output_root_mean_squared_error: 0.5721 - val_loss: 1.2303 - val_y1_output_loss: 0.2906 - val_y2_output_loss: 0.9350 - val_y1_output_root_mean_squared_error: 0.5383 - val_y2_output_root_mean_squared_error: 0.9698
# Epoch 492/500
# 614/614 [==============================] - 0s 119us/sample - loss: 0.4065 - y1_output_loss: 0.1041 - y2_output_loss: 0.3008 - y1_output_root_mean_squared_error: 0.3221 - y2_output_root_mean_squared_error: 0.5502 - val_loss: 0.9052 - val_y1_output_loss: 0.2835 - val_y2_output_loss: 0.6015 - val_y1_output_root_mean_squared_error: 0.5358 - val_y2_output_root_mean_squared_error: 0.7862
# Epoch 493/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.4273 - y1_output_loss: 0.1195 - y2_output_loss: 0.3053 - y1_output_root_mean_squared_error: 0.3463 - y2_output_root_mean_squared_error: 0.5544 - val_loss: 0.8394 - val_y1_output_loss: 0.2380 - val_y2_output_loss: 0.6106 - val_y1_output_root_mean_squared_error: 0.4703 - val_y2_output_root_mean_squared_error: 0.7863
# Epoch 494/500
# 614/614 [==============================] - 0s 120us/sample - loss: 0.4278 - y1_output_loss: 0.1044 - y2_output_loss: 0.3209 - y1_output_root_mean_squared_error: 0.3225 - y2_output_root_mean_squared_error: 0.5691 - val_loss: 0.7593 - val_y1_output_loss: 0.2025 - val_y2_output_loss: 0.5479 - val_y1_output_root_mean_squared_error: 0.4520 - val_y2_output_root_mean_squared_error: 0.7450
# Epoch 495/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3759 - y1_output_loss: 0.1011 - y2_output_loss: 0.2758 - y1_output_root_mean_squared_error: 0.3158 - y2_output_root_mean_squared_error: 0.5255 - val_loss: 1.1716 - val_y1_output_loss: 0.3656 - val_y2_output_loss: 0.8155 - val_y1_output_root_mean_squared_error: 0.5909 - val_y2_output_root_mean_squared_error: 0.9069
# Epoch 496/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3619 - y1_output_loss: 0.0915 - y2_output_loss: 0.2676 - y1_output_root_mean_squared_error: 0.3035 - y2_output_root_mean_squared_error: 0.5194 - val_loss: 0.7709 - val_y1_output_loss: 0.2002 - val_y2_output_loss: 0.5537 - val_y1_output_root_mean_squared_error: 0.4511 - val_y2_output_root_mean_squared_error: 0.7532
# Epoch 497/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3584 - y1_output_loss: 0.0993 - y2_output_loss: 0.2581 - y1_output_root_mean_squared_error: 0.3153 - y2_output_root_mean_squared_error: 0.5089 - val_loss: 0.9566 - val_y1_output_loss: 0.2335 - val_y2_output_loss: 0.7083 - val_y1_output_root_mean_squared_error: 0.4788 - val_y2_output_root_mean_squared_error: 0.8529
# Epoch 498/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.3820 - y1_output_loss: 0.1017 - y2_output_loss: 0.2770 - y1_output_root_mean_squared_error: 0.3204 - y2_output_root_mean_squared_error: 0.5285 - val_loss: 0.9913 - val_y1_output_loss: 0.3029 - val_y2_output_loss: 0.7024 - val_y1_output_root_mean_squared_error: 0.5363 - val_y2_output_root_mean_squared_error: 0.8389
# Epoch 499/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3739 - y1_output_loss: 0.0998 - y2_output_loss: 0.2815 - y1_output_root_mean_squared_error: 0.3146 - y2_output_root_mean_squared_error: 0.5243 - val_loss: 1.3676 - val_y1_output_loss: 0.3748 - val_y2_output_loss: 0.9992 - val_y1_output_root_mean_squared_error: 0.6119 - val_y2_output_root_mean_squared_error: 0.9965
# Epoch 500/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.6790 - y1_output_loss: 0.1612 - y2_output_loss: 0.5167 - y1_output_root_mean_squared_error: 0.4019 - y2_output_root_mean_squared_error: 0.7193 - val_loss: 0.8230 - val_y1_output_loss: 0.2528 - val_y2_output_loss: 0.5830 - val_y1_output_root_mean_squared_error: 0.4879 - val_y2_output_root_mean_squared_error: 0.7648

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 30us/sample - loss: 0.8230 - y1_output_loss: 0.2367 - y2_output_loss: 0.5935 - y1_output_root_mean_squared_error: 0.4879 - y2_output_root_mean_squared_error: 0.7648
# Loss = 0.823008732362227, Y1_loss = 0.23672232031822205, Y1_mse = 0.487897127866745, Y2_loss = 0.5935294032096863, Y2_mse = 0.7648301124572754

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
